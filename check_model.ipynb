# %%
from ultralytics import YOLO

try:
    model = YOLO("ultralytics/cfg/models/11/yolo11m-cbam.yaml").load("yolo11m.pt")
    # model = YOLO("yolo11-cbam.yaml").load("yolo11m.pt")
    print("Berhasil! CBAM sudah terdeteksi di arsitektur.")
    model.info() # Ini akan menampilkan ringkasan layer
except Exception as e:
    print(f"Gagal: {e}")
# Out:
# Transferred 78/659 items from pretrained weights
# Berhasil! CBAM sudah terdeteksi di arsitektur.
# YOLO11m-cbam summary: 239 layers, 20,063,114 parameters, 20,063,098 gradients, 68.2 GFLOPs

# %%
from ultralytics import YOLO

try:
    model2 = YOLO("ultralytics/cfg/models/11/yolo11n-cbam.yaml").load("yolo11n.pt")
    # model = YOLO("yolo11-cbam.yaml").load("yolo11m.pt")
    print("Berhasil! CBAM sudah terdeteksi di arsitektur.")
    model2 .info() # Ini akan menampilkan ringkasan layer
except Exception as e:
    print(f"Gagal: {e}")
# Out:
# Transferred 48/509 items from pretrained weights
# Berhasil! CBAM sudah terdeteksi di arsitektur.
# YOLO11n-cbam summary: 189 layers, 2,590,910 parameters, 2,590,894 gradients, 6.4 GFLOPs

# %%
print(model.model.yaml)
# Out:
# {'nc': 2, 'scale': 'm', 'scales': {'n': [0.5, 0.25, 1024], 's': [0.5, 0.5, 1024], 'm': [0.5, 1.0, 512], 'l': [1.0, 1.0, 512], 'x': [1.0, 1.5, 512]}, 'backbone': [[-1, 1, 'Conv', [64, 3, 2]], [-1, 1, 'Conv', [128, 3, 2]], [-1, 2, 'C3k2', [256, False, 0.25]], [-1, 1, 'CBAM', [256]], [-1, 1, 'Conv', [256, 3, 2]], [-1, 2, 'C3k2', [512, False, 0.25]], [-1, 1, 'Conv', [512, 3, 2]], [-1, 2, 'C3k2', [512, True]], [-1, 1, 'Conv', [1024, 3, 2]], [-1, 2, 'C3k2', [1024, True]], [-1, 1, 'SPPF', [1024, 5]], [-1, 2, 'C2PSA', [1024]]], 'head': [[-1, 1, 'nn.Upsample', ['None', 2, 'nearest']], [[-1, 7], 1, 'Concat', [1]], [-1, 2, 'C3k2', [512, False]], [-1, 1, 'nn.Upsample', ['None', 2, 'nearest']], [[-1, 5], 1, 'Concat', [1]], [-1, 2, 'C3k2', [256, False]], [-1, 1, 'Conv', [256, 3, 2]], [[-1, 14], 1, 'Concat', [1]], [-1, 2, 'C3k2', [512, False]], [-1, 1, 'Conv', [512, 3, 2]], [[-1, 11], 1, 'Concat', [1]], [-1, 2, 'C3k2', [1024, True]], [[17, 20, 23], 1, 'Detect', ['nc']]], 'yaml_file': 'ultralytics\\
# ...
